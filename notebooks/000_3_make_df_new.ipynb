# %% [markdown]
# # 概要
# - trainとtestのbbをまとめる（indexずれを防ぐため）
# - BB1のscaffoldの情報を使って、FOLDを設定する
# - bb1~3と同様にbb1もindex化して列を足し、scaffold用の辞書も準備

# %%
import os
from pathlib import Path

def is_kaggle_kernel():
    return os.path.exists('/kaggle/working')

if is_kaggle_kernel():

    BASE_DIR = Path("/kaggle")
    DATA_DIR = BASE_DIR / "input"
    OUTPUT_DIR = BASE_DIR / "working"
    print('on kaggle notebook')

else:
    BASE_DIR = Path(os.getcwd()) / './../'
    DATA_DIR = BASE_DIR / "data"
    OUTPUT_DIR = BASE_DIR / "output/eda"
    
class paths:    
    DATA_DIR = DATA_DIR
    TRAIN_PATH = DATA_DIR / "train.parquet"
    TEST_PATH = DATA_DIR / "test.parquet"
    OUTPUT_DIR = OUTPUT_DIR
    SHRUNKEN_DATA_DIR = DATA_DIR / "shrunken-train-set"
    
    OUTPUT_DIR.mkdir(exist_ok=True, parents=True)

# %% [markdown]
# # 必要なデータ
# - smiles to indexの辞書, index to smilesの辞書
#     - bb1
#     - bb1 scaffold
#     - bb2, 3 scaffold
#     - bb2, 3 scaffold
#     - main moleculeの scaffoldの辞書
#
# - shrunkenしたテストデータ
#     - train
#     - test（pretrain用）
# - non shrunken test（submitt用）

# %%
# !pip install rdkit

# %%
import os
import gc
import math
import numpy as np
import pandas as pd
from glob import glob
# import duckdb
# import lightgbm as lgb
from tqdm import tqdm
from rdkit import Chem
from rdkit.Chem import Draw

import matplotlib.pyplot as plt
from sklearn.model_selection import KFold
from sklearn.model_selection import StratifiedKFold
from rdkit.Chem.Scaffolds import MurckoScaffold
from funcs.chemical_func import clean_bb1_structure

import pickle

# %%
bb_cols = ['buildingblock1_smiles', 'buildingblock2_smiles','buildingblock3_smiles', 
        #    'molecule_smiles'
           ]
TARGETS = ['binds_BRD4', 'binds_HSA','binds_sEH']

df_train = pd.read_parquet(paths.DATA_DIR / 'shrunken-train-set/train.parquet', columns=bb_cols + TARGETS)
df_test = pd.read_parquet(paths.DATA_DIR / 'shrunken-train-set/test.parquet', columns=bb_cols)

# submit用のtestデータ
df_sub = pd.read_parquet(paths.DATA_DIR / 'test.parquet', columns=['id','protein_name']+bb_cols)

# %%
# building block smiles
# NOTE: trainとtestのindexとsmilesは一致していないっぽい
with open(paths.SHRUNKEN_DATA_DIR / 'train_dicts/BBs_dict_reverse_1.p', 'rb') as file:
    train_dicts_bb1 = pickle.load(file)
with open(paths.SHRUNKEN_DATA_DIR / 'train_dicts/BBs_dict_reverse_2.p', 'rb') as file:
    train_dicts_bb2 = pickle.load(file)
with open(paths.SHRUNKEN_DATA_DIR / 'train_dicts/BBs_dict_reverse_3.p', 'rb') as file:
    train_dicts_bb3 = pickle.load(file)

with open(paths.SHRUNKEN_DATA_DIR / 'test_dicts/BBs_dict_reverse_1_test.p', 'rb') as file:
    test_dicts_bb1 = pickle.load(file)
with open(paths.SHRUNKEN_DATA_DIR / 'test_dicts/BBs_dict_reverse_2_test.p', 'rb') as file:
    test_dicts_bb2 = pickle.load(file)
with open(paths.SHRUNKEN_DATA_DIR / 'test_dicts/BBs_dict_reverse_3_test.p', 'rb') as file:
    test_dicts_bb3= pickle.load(file)

# %% [markdown]
# 一旦smilesに直しておく

# %%
# 一旦smilesに直しておく
df_train['buildingblock1_smiles'] = df_train['buildingblock1_smiles'].map(train_dicts_bb1)
df_train['buildingblock2_smiles'] = df_train['buildingblock2_smiles'].map(train_dicts_bb2)
df_train['buildingblock3_smiles'] = df_train['buildingblock3_smiles'].map(train_dicts_bb3)
df_test['buildingblock1_smiles'] = df_test['buildingblock1_smiles'].map(test_dicts_bb1)
df_test['buildingblock2_smiles'] = df_test['buildingblock2_smiles'].map(test_dicts_bb2)
df_test['buildingblock3_smiles'] = df_test['buildingblock3_smiles'].map(test_dicts_bb3)

# %% [markdown]
# ## smilet to idxの辞書を作成
# trainとtestを合わせた辞書を作成する

# %%
bb1_smiles_train = [smiles for smiles in train_dicts_bb1.values()]
bb2_smiles_train = [smiles for smiles in train_dicts_bb2.values()]
bb3_smiles_train = [smiles for smiles in train_dicts_bb3.values()]
bb1_smiles_test = [smiles for smiles in test_dicts_bb1.values()]
bb2_smiles_test = [smiles for smiles in test_dicts_bb2.values()]
bb3_smiles_test = [smiles for smiles in test_dicts_bb3.values()]

bb1_smiles = sorted(list(set(bb1_smiles_train) | set(bb1_smiles_test)))
bb23_smiles = sorted(list(set(bb2_smiles_train) | set(bb2_smiles_test) | set(bb3_smiles_train) | set(bb3_smiles_test)))

print(len(bb1_smiles), len(bb23_smiles))

# smilesをindexに変換する辞書を作成
bb1_smiles2idx = {smiles: idx for idx, smiles in enumerate(bb1_smiles)}
bb23_smiles2idx = {smiles: idx for idx, smiles in enumerate(bb23_smiles)}
# Out:
# 341 1769

# %% [markdown]
# ## scaffold smilesを作成

# %%
# bb1のscaffoldを取得
bb1_scafold_dict = {}
for smiles in tqdm(bb1_smiles):
    mol = Chem.MolFromSmiles(smiles)
    scaffold = MurckoScaffold.GetScaffoldForMol(mol)
    scaffold_smiles = Chem.MolToSmiles(scaffold)
    
    if scaffold_smiles == '':
        scaffold_smiles = 'C'
    
    bb1_scafold_dict[smiles] = scaffold_smiles

bb23_scafold_dict = {}
for smiles in tqdm(bb23_smiles):
    mol = Chem.MolFromSmiles(smiles)
    scaffold = MurckoScaffold.GetScaffoldForMol(mol)
    scaffold_smiles = Chem.MolToSmiles(scaffold)
    
    if scaffold_smiles == '':
        scaffold_smiles = 'C'
    
    bb23_scafold_dict[smiles] = scaffold_smiles

# scaffoldのリスト
bb1_scaffold_smiles = list(set([smiles for smiles in bb1_scafold_dict.values()]))
bb23_scaffold_smiles = list(set([smiles for smiles in bb23_scafold_dict.values()]))

# scaffoldのsmilesをindexに変換する辞書を作成
bb1_scaffold_smiles2idx = {smiles: idx for idx, smiles in enumerate(bb1_scaffold_smiles)}
bb23_scaffold_smiles2idx = {smiles: idx for idx, smiles in enumerate(bb23_scaffold_smiles)}
# Out:
# 100%|██████████| 341/341 [00:00<00:00, 6217.30it/s]
# 100%|██████████| 1769/1769 [00:00<00:00, 18402.23it/s]

# %%
df_train["buildingblock1_smiles_scaffold"] = df_train["buildingblock1_smiles"].map(bb1_scafold_dict)
df_train["buildingblock2_smiles_scaffold"] = df_train["buildingblock2_smiles"].map(bb23_scafold_dict)
df_train["buildingblock3_smiles_scaffold"] = df_train["buildingblock3_smiles"].map(bb23_scafold_dict)

df_test["buildingblock1_smiles_scaffold"] = df_test["buildingblock1_smiles"].map(bb1_scafold_dict)
df_test["buildingblock2_smiles_scaffold"] = df_test["buildingblock2_smiles"].map(bb23_scafold_dict)
df_test["buildingblock3_smiles_scaffold"] = df_test["buildingblock3_smiles"].map(bb23_scafold_dict)

df_sub["buildingblock1_smiles_scaffold"] = df_sub["buildingblock1_smiles"].map(bb1_scafold_dict)
df_sub["buildingblock2_smiles_scaffold"] = df_sub["buildingblock2_smiles"].map(bb23_scafold_dict)
df_sub["buildingblock3_smiles_scaffold"] = df_sub["buildingblock3_smiles"].map(bb23_scafold_dict)

# %% [markdown]
# ## FOLDは旧版のものを受け継ぐ

# %%
df_fold = pd.read_parquet(paths.DATA_DIR / 'shrunken-train-set/train_fold_only.parquet', columns=['fold'])
df_train["fold"] = df_fold['fold'].values

# foldを分ける
display(df_train['fold'].value_counts())

# >>> fold2のbinds_sEHだけ以上に多い
for fold in range(5):
    print(f'fold{fold}')
    print(df_train[df_train['fold'] == fold][TARGETS].mean())
    print('---')
# Out:
# fold
# 1    31600668
# 4    27966077
# 0    19967499
# 2    10163121
# 3     8718245
# Name: count, dtype: int64
# fold0
# binds_BRD4    0.006064
# binds_HSA     0.004038
# binds_sEH     0.002274
# dtype: float64
# ---
# fold1
# binds_BRD4    0.003272
# binds_HSA     0.004994
# binds_sEH     0.002603
# dtype: float64
# ---
# fold2
# binds_BRD4    0.004564
# binds_HSA     0.002907
# binds_sEH     0.044195
# dtype: float64
# ---
# fold3
# binds_BRD4    0.002707
# binds_HSA     0.003055
# binds_sEH     0.001804
# dtype: float64
# ---
# fold4
# binds_BRD4    0.005811
# binds_HSA     0.004069
# binds_sEH     0.004720
# dtype: float64
# ---

# %% [markdown]
# ## 全てIDXに変換して、変換用の辞書を保存する

# %%
col_order = [
    'buildingblock1_smiles', 'buildingblock2_smiles','buildingblock3_smiles', 
       'buildingblock1_smiles_scaffold', 'buildingblock2_smiles_scaffold','buildingblock3_smiles_scaffold',
       'fold',
       'binds_BRD4', 'binds_HSA', 'binds_sEH']
df_train = df_train[col_order]
df_test = df_test[col_order[:-4]]

# %%
# 全てindexに変換する
def smiles2idx(df):
    df = df.copy()
    df['buildingblock1_smiles'] = df['buildingblock1_smiles'].map(bb1_smiles2idx)
    df['buildingblock2_smiles'] = df['buildingblock2_smiles'].map(bb23_smiles2idx)
    df['buildingblock3_smiles'] = df['buildingblock3_smiles'].map(bb23_smiles2idx)
    df['buildingblock1_smiles_scaffold'] = df['buildingblock1_smiles_scaffold'].map(bb1_scaffold_smiles2idx)
    df['buildingblock2_smiles_scaffold'] = df['buildingblock2_smiles_scaffold'].map(bb23_scaffold_smiles2idx)
    df['buildingblock3_smiles_scaffold'] = df['buildingblock3_smiles_scaffold'].map(bb23_scaffold_smiles2idx)
    return df

df_train = smiles2idx(df_train)
df_test = smiles2idx(df_test)
df_sub = smiles2idx(df_sub)

# %%
df_sub.head()
# Out:
#           id protein_name  buildingblock1_smiles  buildingblock2_smiles  \
# 0  295246830         BRD4                      0                     20
# 1  295246831          HSA                      0                     20
# 2  295246832          sEH                      0                     20
# 3  295246833         BRD4                      0                     20
# 4  295246834          HSA                      0                     20
#
#    buildingblock3_smiles  buildingblock1_smiles_scaffold  \
# 0                     20                              17
# 1                     20                              17
# 2                     20                              17
# 3                    119                              17
# 4                    119                              17
#
#    buildingblock2_smiles_scaffold  buildingblock3_smiles_scaffold
# 0                             116                             116
# 1                             116                             116
# 2                             116                             116
# 3                             116                             438
# 4                             116                             438

# %%
# cleanになったsmilesをindexに変換する辞書を作成
cleaned_bb1_smiles2idx = {clean_bb1_structure(smiles): idx for smiles, idx in bb1_smiles2idx.items()}
cleaned_bb1_smiles2idx
# Out:
# {'C#CCCCC(Nc1nc(N)nc(N)n1)C(=O)NCC': 0,
#  'C#CCC(CC(=O)NCC)Nc1nc(N)nc(N)n1': 4,
#  'C#CCC(Nc1nc(N)nc(N)n1)C(=O)NCC': 5,
#  'C#CCC(C)(Nc1nc(N)nc(N)n1)C(=O)NCC': 3,
#  'C=CCC(CC=C)(Nc1nc(N)nc(N)n1)C(=O)NCC': 6,
#  'C=CCC(Nc1nc(N)nc(N)n1)C(=O)NCC': 10,
#  'C=CCCC(Nc1nc(N)nc(N)n1)C(=O)NCC': 8,
#  'CCNC(=O)C(Cc1ccc(C(C)=O)cc1)Nc1nc(N)nc(N)n1': 11,
#  'CCNC(=O)C(CC(=O)OC(C)(C)C)Nc1nc(N)nc(N)n1': 12,
#  'CCNC(=O)C(CCC(=O)OC(C)(C)C)Nc1nc(N)nc(N)n1': 13,
#  'CCNC(=O)C1C=C(c2ccccc2C)CN1C=O': 14,
#  'CCNC(=O)C1(c2ccc(C)cc2)CCN(C=O)CC1': 15,
#  'CCNC(=O)C1(c2cccc(C)c2)CCN(C=O)CC1': 16,
#  'CCNC(=O)c1ccc(C)cc1OCC1CCN(C=O)CC1': 17,
#  'CCNC(=O)c1ccc(OCC2CCN(C=O)CC2)c(C)c1': 18,
#  'CCNC(=O)c1ccc(C)c(OC2CCN(C=O)CC2)c1': 19,
#  'CCNC(=O)C1C(c2cccc(C)c2)CCCN1C=O': 20,
#  'CCNC(=O)c1cc(C)cn1C1CCCN(C=O)C1': 21,
#  'CCNC(=O)c1cn(C2CCCN(C=O)C2)c2ccc(C)cc12': 22,
#  'CCNC(=O)C1N(C(=O)OC(C)(C)C)CCN1c1nc(N)nc(N)n1': 23,
#  'CCNC(=O)C1(Cc2ccc(C)s2)CCN(C=O)C1': 24,
#  'CCNC(=O)c1ccc(C)cc1OC1CCN(C=O)C1': 25,
#  'CCNC(=O)C1(Cc2ccc(C)cc2)CCN(C=O)C1': 26,
#  'CCNC(=O)C1CN(C=O)CC1c1cccc(C)c1': 27,
#  'CCNC(=O)C1CN(C(=O)OC(C)(C)C)CC1Nc1nc(N)nc(N)n1': 28,
#  'CCNC(=O)C1CC(Oc2cc(C)ccn2)CN1C=O': 29,
#  'CCNC(=O)C1CC(n2cnc(C)c2)CN1C=O': 30,
#  'CCNC(=O)C1CC(n2cncc2C)CN1C=O': 31,
#  'CCNC(=O)C1CC(Oc2ccccc2C)CN1C=O': 32,
#  'CCNC(=O)c1cc(C)cnc1N1CCCC(NC=O)C1': 33,
#  'CCNC(=O)C(COC(C)(C)C)Nc1nc(N)nc(N)n1': 34,
#  'CCNC(=O)C(Cc1ccc(OC(C)(C)C)cc1)Nc1nc(N)nc(N)n1': 35,
#  'CCNC(=O)c1ccc(C(C)(C)C)cc1Nc1nc(N)nc(N)n1': 36,
#  'CCNC(=O)C(Nc1nc(N)nc(N)n1)C(C)C': 37,
#  'CCNC(=O)C(CC(C)C)Nc1nc(N)nc(N)n1': 38,
#  'CCNC(=O)C(C)Nc1nc(N)nc(N)n1': 39,
#  'CCNC(=O)C(Nc1nc(N)nc(N)n1)C(C)OC(C)(C)C': 40,
#  'CCNC(=O)C(Nc1nc(N)nc(N)n1)C(C)CC': 41,
#  'CCCCC(Nc1nc(N)nc(N)n1)C(=O)NCC': 329,
#  'CCNC(=O)c1cc(Cl)c(Nc2nc(N)nc(N)n2)cc1OCC': 43,
#  'CCNC(=O)c1cc(S(=O)(=O)CC)c(Nc2nc(N)nc(N)n2)cc1OC': 44,
#  'CCNC(=O)c1c(CC)cccc1Nc1nc(N)nc(N)n1': 45,
#  'CCNC(=O)CCC1CCCCC1.CNc1nc(N)nc(N)n1': 46,
#  'CCNC(=O)C(Cc1ccc(Cl)cc1)N(C)c1nc(N)nc(N)n1': 47,
#  'CCNC(=O)c1cc(C)nc(N(C)C2CCN(C=O)C2)c1': 48,
#  'CCNC(=O)c1cc(C)cnc1N(C)C1CCNC1': 49,
#  'C.CCNC(=O)CC(Nc1nc(N)nc(N)n1)C(=O)O': 50,
#  'C.CCNC(=O)c1ccc(C(=O)O)c(Nc2nc(N)nc(N)n2)c1': 51,
#  'CCNC(=O)c1ccc(F)c(OC)c1Nc1nc(N)nc(N)n1': 52,
#  'CCNC(=O)c1cc(OC)c(Nc2nc(N)nc(N)n2)cc1N': 53,
#  'CCNC(=O)c1cc(OC)ncc1Nc1nc(N)nc(N)n1': 54,
#  'CCNC(=O)c1ccc(Nc2nc(N)nc(N)n2)c(OC)c1': 55,
#  'CCNC(=O)c1c(Nc2nc(N)nc(N)n2)cc(OC)cc1OC': 56,
#  'CCNC(=O)c1cc(OC)c(OC)cc1Nc1nc(N)nc(N)n1': 57,
#  'CCNC(=O)c1ccc(OC)cc1Nc1nc(N)nc(N)n1': 58,
#  'CCNC(=O)C(Cc1ccc(OC)c(OC)c1)Nc1nc(N)nc(N)n1': 59,
#  'CCNC(=O)c1cc(OC)ccc1Nc1nc(N)nc(N)n1': 60,
#  'CCNC(=O)C(Nc1nc(N)nc(N)n1)c1ccc(OC)cc1': 61,
#  'CCNC(=O)c1cccc(OC)c1Nc1nc(N)nc(N)n1': 62,
#  'CCNC(=O)c1c(Nc2nc(N)nc(N)n2)cccc1OC': 63,
#  'CCNC(=O)c1ccnc(OC)c1Nc1nc(N)nc(N)n1': 64,
#  'CCNC(=O)c1ccc(S(C)(=O)=O)cc1Nc1nc(N)nc(N)n1': 65,
#  'CCNC(=O)C(CCSC)Nc1nc(N)nc(N)n1': 66,
#  'CCNC(=O)c1nc(SC)ncc1Nc1nc(N)nc(N)n1': 67,
#  'CCNC(=O)C(Nc1nc(N)nc(N)n1)C(C)OCc1ccccc1': 68,
#  'CCCC(C)(Nc1nc(N)nc(N)n1)C(=O)NCC': 69,
#  'CCNC(=O)c1ccc(Br)c(C)c1Nc1nc(N)nc(N)n1': 70,
#  'CCNC(=O)c1cc(Nc2nc(N)nc(N)n2)c(C)cc1Br': 71,
#  'CCNC(=O)c1cc(C)cc(Br)c1Nc1nc(N)nc(N)n1': 72,
#  'CCNC(=O)c1cc(Br)cc(C)c1Nc1nc(N)nc(N)n1': 73,
#  'CCNC(=O)c1ccc(Nc2nc(N)nc(N)n2)c(C)c1': 74,
#  'CCNC(=O)c1cc(C)cc(C)c1Nc1nc(N)nc(N)n1': 75,
#  'CCNC(=O)c1cc(Cl)cc(C)c1Nc1nc(N)nc(N)n1': 76,
#  'CCNC(=O)C(Cc1c(C)cc(O)cc1C)Nc1nc(N)nc(N)n1': 77,
#  'CCNC(=O)c1ccc(C)c(C)c1Nc1nc(N)nc(N)n1': 78,
#  'CCNC(=O)c1ccc(C)c(Nc2nc(N)nc(N)n2)c1': 79,
#  'CCNC(=O)CC(Nc1nc(N)nc(N)n1)c1ccc(C)cc1': 80,
#  'CCNC(=O)C(Cc1ccc(C)cc1)Nc1nc(N)nc(N)n1': 81,
#  'CCNC(=O)c1cc(C)ccc1Nc1nc(N)nc(N)n1': 82,
#  'CCNC(=O)c1cccc(C)c1Nc1nc(N)nc(N)n1': 83,
#  'CCNC(=O)c1c(C)cccc1Nc1nc(N)nc(N)n1': 84,
#  'CCNC(=O)C(Cc1ccccc1C)Nc1nc(N)nc(N)n1': 333,
#  'CCNC(=O)CC(Nc1nc(N)nc(N)n1)c1ccccc1C': 86,
#  'CCNC(=O)C(Cc1cn(C)c2ccccc12)Nc1nc(N)nc(N)n1': 87,
#  'CCNC(=O)CC(Cc1ccc(C#N)cc1)Nc1nc(N)nc(N)n1': 90,
#  'CCNC(=O)C(Cc1ccc(C#N)cc1)Nc1nc(N)nc(N)n1': 91,
#  'CCNC(=O)c1cc(C#N)ccc1Nc1nc(N)nc(N)n1': 92,
#  'CCNC(=O)CC(Nc1nc(N)nc(N)n1)c1ccc(C#N)cc1': 93,
#  'CCNC(=O)CC(Cc1cccc(C#N)c1)Nc1nc(N)nc(N)n1': 94,
#  'C1CCCCC1.CCNC(=O)CCC(Nc1nc(N)nc(N)n1)C(=O)O': 95,
#  'CCNC(=O)C(CC1CCCCC1)Nc1nc(N)nc(N)n1': 328,
#  'CCNC(=O)C(CCc1ccccc1)Nc1nc(N)nc(N)n1': 97,
#  'CCNC(=O)C(Cc1ccccc1)Nc1nc(N)nc(N)n1': 327,
#  'CCNC(=O)C1(Nc2nc(N)nc(N)n2)CC1': 99,
#  'CCNC(=O)C1(Nc2nc(N)nc(N)n2)CCC1': 100,
#  'CCNC(=O)C1(Nc2nc(N)nc(N)n2)CCCC1': 101,
#  'CCNC(=O)C1(Nc2nc(N)nc(N)n2)CCCCC1': 102,
#  'CCNC(=O)C1(Nc2nc(N)nc(N)n2)CCOCC1': 103,
#  'CCNC(=O)C1(Nc2nc(N)nc(N)n2)CCc2ccccc21': 104,
#  'CCNC(=O)C1(Nc2nc(N)nc(N)n2)Cc2ccccc2C1': 105,
#  'CCNC(=O)c1cc(C)nc(N2CC(N)C2)c1': 106,
#  'CCNC(=O)C1CCC(CNc2nc(N)nc(N)n2)CC1': 108,
#  'CCNC(=O)c1ccc(CNc2nc(N)nc(N)n2)cc1': 109,
#  'CCNC(=O)c1cccc(CNc2nc(N)nc(N)n2)c1': 110,
#  'CCNC(=O)C(Nc1nc(N)nc(N)n1)C1CCCC1': 140,
#  'CCNC(=O)C(Nc1nc(N)nc(N)n1)C1CCCCC1': 141,
#  'CCNC(=O)C(CC=Cc1ccccc1)Nc1nc(N)nc(N)n1': 113,
#  'CCNC(=O)C(CC1CC1)Nc1nc(N)nc(N)n1': 114,
#  'CCNC(=O)C(CC1CCC1)Nc1nc(N)nc(N)n1': 115,
#  'CCNC(=O)C(CCC1CCCCC1)Nc1nc(N)nc(N)n1': 144,
#  'CCNC(=O)C(Cc1c(F)c(F)c(F)c(F)c1F)Nc1nc(N)nc(N)n1': 117,
#  'CCNC(=O)C(Cc1cc(F)c(F)c(F)c1)Nc1nc(N)nc(N)n1': 118,
#  'CCNC(=O)C(Cc1ccc(Br)cc1)Nc1nc(N)nc(N)n1': 119,
#  'CCNC(=O)C(Cc1ccc(C(F)(F)F)cc1)Nc1nc(N)nc(N)n1': 148,
#  'CCNC(=O)C(Cc1ccc(Cl)c(Cl)c1)Nc1nc(N)nc(N)n1': 149,
#  'CCNC(=O)C(Cc1ccc(Cl)cc1Cl)Nc1nc(N)nc(N)n1': 122,
#  'CCNC(=O)C(Cc1ccc(F)c(F)c1)Nc1nc(N)nc(N)n1': 151,
#  'CCNC(=O)C(Cc1ccc(F)cc1)Nc1nc(N)nc(N)n1': 124,
#  'CCNC(=O)C(Cc1ccc(F)cc1F)Nc1nc(N)nc(N)n1': 125,
#  'CCNC(=O)C(Cc1ccc(I)cc1)Nc1nc(N)nc(N)n1': 152,
#  'CCNC(=O)C(Cc1ccc([N+](=O)[O-])cc1)Nc1nc(N)nc(N)n1': 153,
#  'CCNC(=O)C(Cc1ccccc1F)Nc1nc(N)nc(N)n1': 128,
#  'CCNC(=O)C(Cc1cccnc1)Nc1nc(N)nc(N)n1': 155,
#  'CCNC(=O)C(Cc1ccco1)Nc1nc(N)nc(N)n1': 130,
#  'CCNC(=O)C(Cc1cccs1)Nc1nc(N)nc(N)n1': 131,
#  'CCNC(=O)C(Cc1ccsc1)Nc1nc(N)nc(N)n1': 132,
#  'CCNC(=O)C(Cc1csc2ccccc12)Nc1nc(N)nc(N)n1': 156,
#  'CCNC(=O)C(Cc1cscn1)Nc1nc(N)nc(N)n1': 134,
#  'CCNC(=O)C1CCCC1Nc1nc(N)nc(N)n1': 158,
#  'CCNC(=O)c1cc(C)nc(N2CCC(N)C2)c1': 159,
#  'CCNC(=O)c1cc(C)cnc1N1CCC(N)C1': 160,
#  'CCNC(=O)C1CCC(Nc2nc(N)nc(N)n2)C1': 161,
#  'CCNC(=O)C(Nc1nc(N)nc(N)n1)C1CC1': 139,
#  'CCNC(=O)C(Nc1nc(N)nc(N)n1)c1ccsc1': 142,
#  'CCNC(=O)C(CC1CCCC1)Nc1nc(N)nc(N)n1': 143,
#  'CCOC(=O)[C@@H](Cc1c[nH]c2cc(Cl)ccc12)Nc3nc(N)nc(N)n3': 145,
#  'CCNC(=O)C(Cc1cc(F)cc(F)c1)Nc1nc(N)nc(N)n1': 146,
#  'CCNC(=O)C(Cc1ccc(-c2ccccc2)cc1)Nc1nc(N)nc(N)n1': 147,
#  'CCNC(=O)C(Cc1ccc(Cl)cc1)Nc1nc(N)nc(N)n1': 150,
#  'CCNC(=O)C(Cc1ccccc1Cl)Nc1nc(N)nc(N)n1': 154,
#  'CCNC(=O)C1C=CC(Nc2nc(N)nc(N)n2)C1': 157,
#  'CCNC(=O)C1CCC(Nc2nc(N)nc(N)n2)CC1': 162,
#  'CCNC(=O)c1cc(Br)c(Nc2nc(N)nc(N)n2)c(Br)c1': 163,
#  'CCNC(=O)c1cc(F)cc(Br)c1Nc1nc(N)nc(N)n1': 164,
#  'CCNC(=O)c1cccc(Br)c1Nc1nc(N)nc(N)n1': 165,
#  'CCNC(=O)c1cc(Cl)c(Br)c(F)c1Nc1nc(N)nc(N)n1': 166,
#  'CCNC(=O)c1ccc(Br)c(F)c1Nc1nc(N)nc(N)n1': 167,
#  'CCNC(=O)c1ccc2ccccc2c1Nc1nc(N)nc(N)n1': 168,
#  'CCNC(=O)c1cccc(C(=O)O)c1Nc1nc(N)nc(N)n1': 169,
#  'CCNC(=O)c1cccc([N+](=O)[O-])c1Nc1nc(N)nc(N)n1': 170,
#  'CCNC(=O)c1cnn(-c2ccc(F)cc2)c1Nc1nc(N)nc(N)n1': 171,
#  'CCNC(=O)c1cnn(CCO)c1Nc1nc(N)nc(N)n1': 172,
#  'CCNC(=O)c1sc2ncccc2c1Nc1nc(N)nc(N)n1': 173,
#  'CCNC(=O)c1nc(Cl)c(Cl)c(Nc2nc(N)nc(N)n2)c1Cl': 174,
#  'CCNC(=O)c1cc(Cl)c(Nc2nc(N)nc(N)n2)c2c1OCC2': 175,
#  'CCNC(=O)c1nc(Cl)cc(Cl)c1Nc1nc(N)nc(N)n1': 176,
#  'CCNC(=O)c1cc(F)cc(Cl)c1Nc1nc(N)nc(N)n1': 177,
#  'CCNC(=O)c1cccc(Cl)c1Nc1nc(N)nc(N)n1': 178,
#  'CCNC(=O)c1cc(Br)cc(F)c1Nc1nc(N)nc(N)n1': 179,
#  'CCNC(=O)c1cc(F)c(Nc2nc(N)nc(N)n2)c(F)c1': 180,
#  'CCNC(=O)c1cc(F)cc(F)c1Nc1nc(N)nc(N)n1': 181,
#  'CCNC(=O)c1c(Br)ccc(F)c1Nc1nc(N)nc(N)n1': 182,
#  'CCNC(=O)c1c(Cl)ccc(F)c1Nc1nc(N)nc(N)n1': 183,
#  'CCNC(=O)c1cccc(F)c1Nc1nc(N)nc(N)n1': 184,
#  'CCNC(=O)c1c(I)c(Nc2nc(N)nc(N)n2)c(I)c(C(=O)O)c1I': 185,
#  'CCNC(=O)c1cccc(I)c1Nc1nc(N)nc(N)n1': 186,
#  'CCNC(=O)c1cccc(OC(F)(F)F)c1Nc1nc(N)nc(N)n1': 187,
#  'CCNC(=O)c1ccc(-n2cccn2)cc1Nc1nc(N)nc(N)n1': 188,
#  'CCNC(=O)c1cc(Cl)c(Br)cc1Nc1nc(N)nc(N)n1': 189,
#  'CCNC(=O)c1cc(F)c(Br)cc1Nc1nc(N)nc(N)n1': 190,
#  'CCNC(=O)c1cc(Br)cc(Nc2nc(N)nc(N)n2)c1': 191,
#  'CCNC(=O)c1ccc(Br)cc1Nc1nc(N)nc(N)n1': 192,
#  'CCNC(=O)c1ncc(Br)cc1Nc1nc(N)nc(N)n1': 193,
#  'CCNC(=O)c1cc(Nc2nc(N)nc(N)n2)cc(C(=O)O)c1': 194,
#  'CCNC(=O)c1ccc(Br)c(Nc2nc(N)nc(N)n2)c1': 195,
#  'CCNC(=O)c1ccc(C(=O)O)c(Nc2nc(N)nc(N)n2)c1': 196,
#  'CCNC(=O)c1ccc(C(F)(F)F)c(Nc2nc(N)nc(N)n2)c1': 197,
#  'CCNC(=O)c1ccc(Cl)c(Nc2nc(N)nc(N)n2)c1': 198,
#  'CCNC(=O)c1ccc(F)c(Nc2nc(N)nc(N)n2)c1': 199,
#  'CCNC(=O)c1ccc(O)c(Nc2nc(N)nc(N)n2)c1': 200,
#  'CCNC(=O)c1ccc(C(F)(F)F)cc1Nc1nc(N)nc(N)n1': 201,
#  'CCNC(=O)c1cnc(Nc2nc(N)nc(N)n2)cc1Cl': 202,
#  'CCNC(=O)c1cc(Cl)cc(Nc2nc(N)nc(N)n2)c1': 203,
#  'CCNC(=O)c1ccc(Cl)cc1Nc1nc(N)nc(N)n1': 204,
#  'CCNC(=O)c1nc(Cl)cc(Nc2nc(N)nc(N)n2)c1Cl': 205,
#  'CCNC(=O)c1cnc(Cl)cc1Nc1nc(N)nc(N)n1': 206,
#  'CCNC(=O)c1cc(Br)c(F)cc1Nc1nc(N)nc(N)n1': 207,
#  'CCNC(=O)c1cc(F)c(F)cc1Nc1nc(N)nc(N)n1': 208,
#  'CCNC(=O)c1c(F)cc(F)cc1Nc1nc(N)nc(N)n1': 209,
#  'CCNC(=O)c1ccc(F)cc1Nc1nc(N)nc(N)n1': 210,
#  'CCNC(=O)c1ccc(I)cc1Nc1nc(N)nc(N)n1': 211,
#  'CCNC(=O)c1cc(O)cc(Nc2nc(N)nc(N)n2)c1': 212,
#  'CCNC(=O)c1ccc([N+](=O)[O-])cc1Nc1nc(N)nc(N)n1': 213,
#  'CCNC(=O)c1cc2ccccc2cc1Nc1nc(N)nc(N)n1': 214,
#  'CCNC(=O)c1cc(Nc2nc(N)nc(N)n2)ccc1Br': 215,
#  'CCNC(=O)c1cc(Br)ccc1Nc1nc(N)nc(N)n1': 216,
#  'CCNC(=O)c1ccc(Nc2nc(N)nc(N)n2)cc1C(=O)O': 217,
#  'CCNC(=O)c1ccc(Nc2nc(N)nc(N)n2)cc1C(F)(F)F': 218,
#  'CCNC(=O)c1ccc(Nc2nc(N)nc(N)n2)cc1Cl': 219,
#  'CCNC(=O)c1ccc(Nc2nc(N)nc(N)n2)cc1F': 220,
#  'CCNC(=O)c1ccc(Nc2nc(N)nc(N)n2)cc1[N+](=O)[O-]': 221,
#  'CCNC(=O)c1ccc(Nc2nc(N)nc(N)n2)cc1': 222,
#  'CCNC(=O)c1ccc(Nc2nc(N)nc(N)n2)c(Br)c1': 223,
#  'CCNC(=O)c1ccc(Nc2nc(N)nc(N)n2)c(C(F)(F)F)c1': 224,
#  'CCNC(=O)c1ccc(Nc2nc(N)nc(N)n2)c(Cl)c1': 225,
#  'CCNC(=O)c1ccc(Nc2nc(N)nc(N)n2)c(F)c1': 226,
#  'CCNC(=O)c1ccc(Nc2nc(N)nc(N)n2)c(O)c1': 227,
#  'CCNC(=O)c1ccc(Nc2nc(N)nc(N)n2)c(OC(F)(F)F)c1': 228,
#  'CCNC(=O)c1ccc(Nc2nc(N)nc(N)n2)c([N+](=O)[O-])c1': 229,
#  'CCNC(=O)c1ccc(Nc2nc(N)nc(N)n2)nc1': 230,
#  'CCNC(=O)c1ccc(Nc2nc(N)nc(N)n2)cn1': 231,
#  'CCNC(=O)c1cc(C(F)(F)F)ccc1Nc1nc(N)nc(N)n1': 232,
#  'CCNC(=O)c1cc(Nc2nc(N)nc(N)n2)ccc1Cl': 233,
#  'CCNC(=O)c1cc(Cl)ccc1Nc1nc(N)nc(N)n1': 234,
#  'CCNC(=O)c1nc(Cl)ccc1Nc1nc(N)nc(N)n1': 235,
#  'CCNC(=O)c1c(F)ccc(Nc2nc(N)nc(N)n2)c1F': 236,
#  'CCNC(=O)c1cc(F)ccc1Nc1nc(N)nc(N)n1': 237,
#  'CCNC(=O)c1cc(I)ccc1Nc1nc(N)nc(N)n1': 238,
#  'CCNC(=O)c1cc(Nc2nc(N)nc(N)n2)ccc1[N+](=O)[O-]': 239,
#  'CCNC(=O)c1cc([N+](=O)[O-])ccc1Nc1nc(N)nc(N)n1': 240,
#  'CCNC(=O)c1ccc2cc(Nc3nc(N)nc(N)n3)ccc2c1': 241,
#  'CCNC(=O)c1cccc(-c2cccc(Nc3nc(N)nc(N)n3)c2O)c1': 242,
#  'CCNC(=O)c1c(Br)cccc1Nc1nc(N)nc(N)n1': 243,
#  'CCNC(=O)c1cccc(Nc2nc(N)nc(N)n2)c1': 244,
#  'CCNC(=O)c1cccc(Nc2nc(N)nc(N)n2)c1C(=O)O': 245,
#  'CCNC(=O)c1c(Cl)cccc1Nc1nc(N)nc(N)n1': 246,
#  'CCNC(=O)c1c(F)cccc1Nc1nc(N)nc(N)n1': 247,
#  'CCNC(=O)c1c(I)cccc1Nc1nc(N)nc(N)n1': 248,
#  'CCNC(=O)c1c([N+](=O)[O-])cccc1Nc1nc(N)nc(N)n1': 249,
#  'CCNC(=O)c1ccccc1C(=O)c1ccccc1Nc1nc(N)nc(N)n1': 250,
#  'CCNC(=O)c1ncccc1Nc1nc(N)nc(N)n1': 251,
#  'CCNC(=O)c1cc(Nc2nc(N)nc(N)n2)ccn1': 252,
#  'CCNC(=O)c1cc(Cl)ncc1Nc1nc(N)nc(N)n1': 253,
#  'CCNC(=O)c1cncc(Nc2nc(N)nc(N)n2)n1': 254,
#  'CCNC(=O)c1ccncc1Nc1nc(N)nc(N)n1': 255,
#  'CCNC(=O)c1ccc(-c2csc(Nc3nc(N)nc(N)n3)n2)cc1': 256,
#  'CCNC(=O)c1sc(Nc2nc(N)nc(N)n2)nc1C(F)(F)F': 257,
#  'CCNC(=O)c1ccc(Cl)nc1Nc1nc(N)nc(N)n1': 258,
#  'CCOC(=O)c3ccc2[nH]c(c1nc(N)nc(N)n1)nc2c3': 259,
#  'CCNC(=O)c1ccc2nc(Nc3nc(N)nc(N)n3)sc2c1': 260,
#  'CCOC(=O)c4ccc(NCc3cnc2nc(c1nc(N)nc(N)n1)[nH]c(=O)c2n3)cc4': 261,
#  'CCNC(=O)c1cc(Br)cnc1Nc1nc(N)nc(N)n1': 262,
#  'CCNC(=O)c1nc(Br)cnc1Nc1nc(N)nc(N)n1': 263,
#  'CCNC(=O)c1cnc(Nc2nc(N)nc(N)n2)s1': 264,
#  'CCNC(=O)c1nccnc1Nc1nc(N)nc(N)n1': 265,
#  'CCCC(Nc1nc(N)nc(N)n1)C(=O)NCC': 319,
#  'CCNC(=O)C(C)CCNc1nc(N)nc(N)n1': 267,
#  'CCNC(=O)C(C)CNc1nc(N)nc(N)n1': 268,
#  'CCNC(=O)C(Nc1nc(N)nc(N)n1)c1ccccc1C': 269,
#  'CCNC(=O)CC(Nc1nc(N)nc(N)n1)c1ccc(Br)cc1': 289,
#  'CCNC(=O)CC1(CNc2nc(N)nc(N)n2)CCCCC1': 271,
#  'CCNC(=O)CC1(Nc2nc(N)nc(N)n2)CCCCC1': 272,
#  'CCNC(=O)CCNc1nc(N)nc(N)n1': 273,
#  'CCNC(=O)CNc1nc(N)nc(N)n1': 274,
#  'CCOC(=O)COC[C@H]1CCCN1c2nc(N)nc(N)n2': 275,
#  'CCNC(=O)COc1cccc(-c2csc(Nc3nc(N)nc(N)n3)n2)c1': 276,
#  'CCNC(=O)CC(Cc1c(F)c(F)c(F)c(F)c1F)Nc1nc(N)nc(N)n1': 299,
#  'CCNC(=O)CC(Cc1ccc(Br)cc1)Nc1nc(N)nc(N)n1': 300,
#  'CCNC(=O)CC(Cc1ccc(C(F)(F)F)cc1)Nc1nc(N)nc(N)n1': 301,
#  'CCNC(=O)CC(Cc1ccc(Cl)c(Cl)c1)Nc1nc(N)nc(N)n1': 302,
#  'CCNC(=O)CC(Cc1ccc(Cl)cc1)Nc1nc(N)nc(N)n1': 303,
#  'CCNC(=O)CC(Cc1ccc(Cl)cc1Cl)Nc1nc(N)nc(N)n1': 304,
#  'CCNC(=O)CC(Cc1ccc(F)cc1)Nc1nc(N)nc(N)n1': 305,
#  'CCNC(=O)CC(Cc1ccc(I)cc1)Nc1nc(N)nc(N)n1': 306,
#  'CCNC(=O)CC(Cc1ccc([N+](=O)[O-])cc1)Nc1nc(N)nc(N)n1': 307,
#  'CCNC(=O)CC(Cc1cccc(F)c1)Nc1nc(N)nc(N)n1': 286,
#  'CCNC(=O)CC(Cc1ccccc1Cl)Nc1nc(N)nc(N)n1': 287,
#  'CCNC(=O)CC(Cc1cccs1)Nc1nc(N)nc(N)n1': 308,
#  'CCNC(=O)CC(Nc1nc(N)nc(N)n1)c1ccc(C(F)(F)F)cc1': 290,
#  'CCNC(=O)CC(Nc1nc(N)nc(N)n1)c1ccc(Cl)cc1': 291,
#  'CCNC(=O)CC(Nc1nc(N)nc(N)n1)c1ccc(Cl)cc1Cl': 292,
#  'CCNC(=O)CC(Nc1nc(N)nc(N)n1)c1cccc(Cl)c1': 293,
#  'CCNC(=O)CC(Nc1nc(N)nc(N)n1)c1cccc([N+](=O)[O-])c1': 294,
#  'CCNC(=O)CC(Nc1nc(N)nc(N)n1)c1cccnc1': 295,
#  'CCNC(=O)CC(Nc1nc(N)nc(N)n1)c1cccs1': 296,
#  'CCCC(CC(=O)NCC)Nc1nc(N)nc(N)n1': 312,
#  'CCNC(=O)CC(CC=Cc1ccccc1)Nc1nc(N)nc(N)n1': 298,
#  'CCNC(=O)CC(Cc1csc2ccccc12)Nc1nc(N)nc(N)n1': 309,
#  'CCNC(=O)CC(Nc1nc(N)nc(N)n1)c1ccc(F)cc1': 310,
#  'CCNC(=O)CC(Nc1nc(N)nc(N)n1)c1cccc(Cl)c1Cl': 311,
#  'CCNC(=O)CC(Cc1ccccc1C)Nc1nc(N)nc(N)n1': 313,
#  'CCNC(=O)Cc1ccc(Nc2nc(N)nc(N)n2)cc1': 314,
#  'CCNC(=O)C1C=C(c2ccc(C)nc2)CN1': 315,
#  'CCNC(=O)C1C=C(c2ccnc(C)c2)CN1': 316,
#  'CCNC(=O)C1C=C(c2cnc(C)nc2)CN1': 317,
#  'CCCC(Nc1nc(N)nc(N)n1)C(=O)N1CCCC1C(=O)NCC': 320,
#  'CCNC(=O)C1CNCC1c1ccc(C)nc1': 321,
#  'CCNC(=O)C1CNCC1c1ccnc(C)c1': 322,
#  'CCNC(=O)C(CSC)Nc1nc(N)nc(N)n1': 323,
#  'CCNC(=O)C(Cc1ccc(O)cc1C)Nc1nc(N)nc(N)n1': 325,
#  'CCNC(=O)C(CC)Nc1nc(N)nc(N)n1': 330,
#  'CCNC(=O)C(COCC)Nc1nc(N)nc(N)n1': 331,
#  'CCNC(=O)C(CC(C)O)Nc1nc(N)nc(N)n1': 332,
#  'CCNC(=O)c1cc(C)cnc1N1CCCNCC1': 334,
#  'CCNC(=O)c1cc(C)cnc1N1CCNCC1': 335,
#  'CCNC(=O)c1cc(C)nc(N2CCCNCC2)c1': 336,
#  'CCNC(=O)c1cc(C)nc(N2CCNCC2)c1': 337,
#  'CCNC(=O)C1(Cc2ccnc(C)c2)CCNC1': 338,
#  'CCNC(=O)C1(Cc2ccnc(C)c2)CCNCC1': 339,
#  'CCOC(=O)[C@H](CCCN=N#N)Nc1nc(N)nc(N)n1': 340}

# %%
## 保存
SAVE_DIR = paths.DATA_DIR / 'shrunken-data'
SAVE_DIR.mkdir(exist_ok=True, parents=True)

df_train.to_parquet(SAVE_DIR / 'train.parquet')
df_test.to_parquet(SAVE_DIR / 'test.parquet')
df_sub.to_parquet(SAVE_DIR / 'sub.parquet')

with open(SAVE_DIR / 'bb1_smiles2idx.pickle', mode='wb') as f:
    pickle.dump(bb1_smiles2idx, f)
with open(SAVE_DIR / 'bb23_smiles2idx.pickle', mode='wb') as f:
    pickle.dump(bb23_smiles2idx, f)
with open(SAVE_DIR / 'bb1_scaffold_smiles2idx.pickle', mode='wb') as f:
    pickle.dump(bb1_scaffold_smiles2idx, f)
with open(SAVE_DIR / 'bb23_scaffold_smiles2idx.pickle', mode='wb') as f:
    pickle.dump(bb23_scaffold_smiles2idx, f)

with open(SAVE_DIR / 'cleaned_bb1_smiles2idx.pickle', mode='wb') as f:
    pickle.dump(cleaned_bb1_smiles2idx, f)
